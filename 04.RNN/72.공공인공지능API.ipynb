# %% [markdown]
# # 공공 인공지능 Open API 활용

# %%
with open('etriaikey.txt') as file:
    ai_key = file.read()

# %% [markdown]
# # 객체 검출
# ## 1. 하나의 객체 검출

# %%
# JFIF 타입은 JPG로 변경
img_file = 'sparrow.jpg'
img_type = img_file.split('.')[-1]
img_type = 'jpg' if img_type == 'jfif' else img_type

# %%
import urllib3, json, base64
openApiURL = "http://aiopen.etri.re.kr:8000/ObjectDetect"

# %%
with open(img_file, "rb") as file:
    img_contents = base64.b64encode(file.read()).decode("utf8")
img_contents[:10]
# Out:
# '/9j/4AAQSk'

# %%
request_json = {
    "access_key": ai_key,
    "argument": {
        "type": img_type,
        "file": img_contents
    }
}

# %%
http = urllib3.PoolManager()
response = http.request(
    "POST",
    openApiURL,
    headers={"Content-Type": "application/json; charset=UTF-8"},
    body=json.dumps(request_json)
)

# %%
response.status
# Out:
# 200

# %%
response.data
# Out:
# b'{"result":0,"return_object":{"data":[{"class":"bird","confidence":"0.999329","x":"23","y":"20","width":"186","height":"130"}]}}'

# %%
result = json.loads(response.data)
result
# Out:
# {'result': 0,
#  'return_object': {'data': [{'class': 'bird',
#     'confidence': '0.999329',
#     'x': '23',
#     'y': '20',
#     'width': '186',
#     'height': '130'}]}}

# %%
obj_list = result['return_object']['data']
obj_list[0]
# Out:
# {'class': 'bird',
#  'confidence': '0.999329',
#  'x': '23',
#  'y': '20',
#  'width': '186',
#  'height': '130'}

# %% [markdown]
# - 시각화

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# %%
img = Image.open(img_file)
plt.imshow(img);

# %%
draw = ImageDraw.Draw(img)
obj = obj_list[0]
name = obj['class']
x, y = int(obj['x']), int(obj['y'])
w, h = int(obj['width']), int(obj['height'])
draw.rectangle(((x,y), (x+w,y+h)), outline=(255,0,0), width=1)
draw.text((x+10, y-10), name, font=ImageFont.truetype('AppleGothic',10), fill=(255,0,0))
plt.imshow(img);

# %%
# JFIF 타입은 JPG로 변경
img_file = 'animals/crocodile.jpg'
img_type = img_file.split('.')[-1]
img_type = 'jpg' if img_type == 'jfif' else img_type

# %%
with open(img_file, "rb") as file:
    img_contents = base64.b64encode(file.read()).decode("utf8")
img_contents[:10]
# Out:
# '/9j/4AAQSk'

# %%
request_json = {
    "access_key": ai_key,
    "argument": {
        "type": img_type,
        "file": img_contents
    }
}

# %%
response = http.request(
    "POST",
    openApiURL,
    headers={"Content-Type": "application/json; charset=UTF-8"},
    body=json.dumps(request_json)
)

# %%
result = json.loads(response.data)

# %%
obj_list = result['return_object']['data']
obj_list[0]
# Out:
# {'class': 'elephant',
#  'confidence': '0.966966',
#  'x': '81',
#  'y': '186',
#  'width': '1834',
#  'height': '1056'}

# %%
img = Image.open(img_file)
plt.imshow(img);

# %%
draw = ImageDraw.Draw(img)
for obj in obj_list:
    name = obj['class']
    x, y = int(obj['x']), int(obj['y'])
    w, h = int(obj['width']), int(obj['height'])
    draw.rectangle(((x,y), (x+w,y+h)), outline=(255,0,0), width=3)
    draw.text((x+10, y-50), name, font=ImageFont.truetype('AppleGothic',40), fill=(255,0,0))

# %%
plt.figure(figsize=(12,8))
plt.imshow(img);
